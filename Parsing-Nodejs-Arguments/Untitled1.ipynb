# %%
This notebook is used like a utility to create, copy and edit files.

# %%
import os
os.getcwd()
# Out:
# '/home/jack/Desktop/nodejs-projects-lbry/Parsing-Nodejs-Arguments'

# %%
# !cp yourscript.js  yourscript2.js

# %%
# %%writefile claim_list.js
# #!/usr/local/bin/node
# const { exec } = require('child_process');
# var yourscript = exec('lbrynet claim list',
#         (error, stdout, stderr) => {
#             console.log(stdout);
#             console.log(stderr);
#
#             console.log("Last five lines: \n\n"+ stdout.slice(stdout.length - 78));
#             if (error !== null) {
#                 console.log(`exec error: ${error}`);
#             }
#         });
#
# module.exports.yourscript
# Out:
# Overwriting claim_list.js

# %%
# !chmod +x  claim_list.js

# %%
# !./claim_list.js
# Out:
# {
#   "items": [
#     {
#       "address": "bDyZqrP3KoUVjotbdiRsPgkXpqHvASLPrT",
#       "amount": "0.01",
#       "claim_id": "c9e50e32fde32d0a925360fcea378ec8d96a9a13",
#       "claim_op": "create",
#       "confirmations": 2507,
#       "height": 720142,
#       "is_change": true,
#       "is_channel_signature_valid": true,
#       "is_mine": true,
#       "meta": {},
#       "name": "computer-graphics-javascript-graphics",
#       "normalized_name": "computer-graphics-javascript-graphics",
#       "nout": 0,
#       "permanent_url": "lbry://computer-graphics-javascript-graphics#c9e50e32fde32d0a925360fcea378ec8d96a9a13",
#       "signing_channel": {
#         "address": "bDyZqrP3KoUVjotbdiRsPgkXpqHvASLPrT",
#         "amount": "0.005",
#         "claim_id": "d66948527ed2bf54a0e76e2ffe76467cc39e72e4",
#         "claim_op": "update",
#         "confirmations": 33571,
#         "has_signing_key": true,
#         "height": 689078,
#         "is_change": true,
# ...

# %%
# %%writefile claim_search.js
# #!/usr/local/bin/node
# const { exec } = require('child_process');
# var yourscript = exec('lbrynet claim search',
#         (error, stdout, stderr) => {
#             console.log(stdout);
#             console.log(stderr);
#
#             console.log("Last five lines: \n\n"+ stdout.slice(stdout.length - 78));
#             if (error !== null) {
#                 console.log(`exec error: ${error}`);
#             }
#         });
#
# module.exports.yourscript
# Out:
# Overwriting claim_list.js
